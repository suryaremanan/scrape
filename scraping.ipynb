# %%
# Import libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object
url = 'https://lightning.nsstc.nasa.gov/isslisib/lisfound.exe?origin=ST&lat=8.5&lon=76.5&alat=2&alon=2&donob=both&2017.3=on&2017.4=on&2017.5=on&2017.6=on&2017.7=on&2017.8=on&2017.9=on&2017.10=on&2017.11=on&2017.12=on'

# %%
# Create object page
page = requests.get(url)

# %%
# parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="en">
# <head>
# <title>LIS ISS Space Time Domain Search Results</title>
# <!-- Google 360 Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WNP7MLF');</script>
# <!-- End Google 360 Tag Manager -->
# <link href="/common/lisib.css" rel="stylesheet" type="text/css"/>
# <style type="text/css">
# body {
# 	background-color: #EEEEEE;
# 	text-align: center;
# }
# body table tr td table {
# 	text-align: left;
# }
# .subhead_white .white_title .white_title {
# 	text-align: left;
# }
# ul.MenuBarHorizontal a {
#     color: #F5D238;
#     background-color: #485A6E;
# }
# ...

# %%
# Obtain information from tag <table>
table1 = soup.find('table', id='flashtitle')
table1

# %%
# Obtain every title of columns with tag <th>
headers = []
for i in table1.find_all('th'):
 title = i.text
 headers.append(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 # Obtain every title of columns with tag <th>
#       2 headers = []
# ----> 3 for i in table1.find_all('th'):
#       4  title = i.text
#       5  headers.append(title)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# !pip install html-table-parser-python3

# %%
# Library for opening url and creating 
# requests
import urllib.request

# pretty-print python data structures
from pprint import pprint

# for parsing all the tables present 
# on the website
from html_table_parser.parser import HTMLTableParser

# for converting the parsed data in a
# pandas dataframe
import pandas as pd

# %%
# Opens a website and read its
# binary contents (HTTP Response Body)
def url_get_contents(url):

    # Opens a website and read its
    # binary contents (HTTP Response Body)

    #making request to the website
    req = urllib.request.Request(url=url)
    f = urllib.request.urlopen(req)

    #reading contents of the website
    return f.read()

# %%
# defining the html contents of a URL.
xhtml = url_get_contents('https://lightning.nsstc.nasa.gov/isslisib/tmp/lisflashes-61.3.70.109.txt')
# Defining the HTMLTableParser object
p = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p.feed(xhtml)

# Now finally obtaining the data of
# the table required
pprint(p.tables[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 8>()
#       4 p = HTMLTableParser()
#       6 # feeding the html contents in the
#       7 # HTMLTableParser object
# ----> 8 p.feed(xhtml)
#      10 # Now finally obtaining the data of
#      11 # the table required
#      12 pprint(p.tables[1])
#
# File ~\anaconda3\lib\html\parser.py:109, in HTMLParser.feed(self, data)
#     103 def feed(self, data):
#     104     r"""Feed data to the parser.
#     105
#     106     Call this as often as you want, with as little or as much text
#     107     as you want (may include '\n').
#     108     """
# --> 109     self.rawdata = self.rawdata + data
#     110     self.goahead(0)
#
# TypeError: can only concatenate str (not "bytes") to str

# %%
tables=pd.read_html('https://lightning.nsstc.nasa.gov/isslisib/lisfound.exe?origin=ST&lat=8.5&lon=76.5&alat=2&alon=2&donob=both&2017.3=on&2017.4=on&2017.5=on&2017.6=on&2017.7=on&2017.8=on&2017.9=on&2017.10=on&2017.11=on&2017.12=on')

# %%
print("There are : ",len(tables)," tables")
print("Take look at table 0")
print(tables[8])
# Out:
# There are :  12  tables
# Take look at table 0
#                                           0   1         2   3  \
# 0                                 File name NaN       NaN NaN
# 1   ISS_LIS_SC_V2.1_20170311_050549_FIN.hdf NaN  [Mar 11] NaN
# 2   ISS_LIS_SC_V2.1_20170315_170710_FIN.hdf NaN  [Mar 15] NaN
# 3   ISS_LIS_SC_V2.1_20170326_231013_FIN.hdf NaN  [Mar 26] NaN
# 4   ISS_LIS_SC_V2.1_20170327_221901_FIN.hdf NaN  [Mar 27] NaN
# 5   ISS_LIS_SC_V2.1_20170329_112105_FIN.hdf NaN  [Mar 29] NaN
# 6   ISS_LIS_SC_V2.1_20170409_172456_FIN.hdf NaN  [Apr 09] NaN
# 7   ISS_LIS_SC_V2.1_20170423_114033_FIN.hdf NaN  [Apr 23] NaN
# 8   ISS_LIS_SC_V2.1_20170426_103947_FIN.hdf NaN  [Apr 26] NaN
# 9   ISS_LIS_SC_V2.1_20170429_093931_FIN.hdf NaN  [Apr 29] NaN
# 10  ISS_LIS_SC_V2.1_20170504_205101_FIN.hdf NaN  [May 04] NaN
# 11  ISS_LIS_SC_V2.1_20170514_165918_FIN.hdf NaN  [May 14] NaN
# 12  ISS_LIS_SC_V2.1_20170517_155859_FIN.hdf NaN  [May 17] NaN
# ...

# %%
flashes=tables[8]

# %%
flashes.to_csv('sample_flashes.csv')

# %%
tables=pd.read_html('https://lightning.nsstc.nasa.gov/isslisib/tmp/lisflashes-61.3.70.109.txt')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 tables=pd.read_html('https://lightning.nsstc.nasa.gov/isslisib/tmp/lisflashes-61.3.70.109.txt')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
# ...

# %%
sample=tables[8].head(33)

# %%
sample.head()
# Out:
#                                          0   1         2   3  \
# 0                                File name NaN       NaN NaN
# 1  ISS_LIS_SC_V2.1_20170311_050549_FIN.hdf NaN  [Mar 11] NaN
# 2  ISS_LIS_SC_V2.1_20170315_170710_FIN.hdf NaN  [Mar 15] NaN
# 3  ISS_LIS_SC_V2.1_20170326_231013_FIN.hdf NaN  [Mar 26] NaN
# 4  ISS_LIS_SC_V2.1_20170327_221901_FIN.hdf NaN  [Mar 27] NaN
#
#                     4   5                   6        7
# 0    Start time (UTC) NaN      End time (UTC)  Flashes
# 1  2017-070T05:05:49Z NaN  2017-070T06:38:24Z        3
# 2  2017-074T17:07:10Z NaN  2017-074T18:39:46Z       61
# 3  2017-085T23:10:13Z NaN  2017-086T00:42:48Z       34
# 4  2017-086T22:19:01Z NaN  2017-086T23:51:36Z        2

# %%
sample.drop(sample.columns[0], axis=1, inplace=True)
# Out:
# C:\Users\ksury\AppData\Local\Temp\ipykernel_10704\643039400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample.drop(sample.columns[0], axis=1, inplace=True)

# %%
sample.head()
# Out:
#     1         2   3                   4   5                   6        7
# 0 NaN       NaN NaN    Start time (UTC) NaN      End time (UTC)  Flashes
# 1 NaN  [Mar 11] NaN  2017-070T05:05:49Z NaN  2017-070T06:38:24Z        3
# 2 NaN  [Mar 15] NaN  2017-074T17:07:10Z NaN  2017-074T18:39:46Z       61
# 3 NaN  [Mar 26] NaN  2017-085T23:10:13Z NaN  2017-086T00:42:48Z       34
# 4 NaN  [Mar 27] NaN  2017-086T22:19:01Z NaN  2017-086T23:51:36Z        2

# %%
sample.drop(sample.columns[0], axis=1, inplace=True)
# Out:
# C:\Users\ksury\AppData\Local\Temp\ipykernel_10704\643039400.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample.drop(sample.columns[0], axis=1, inplace=True)

# %%
sample.head()
# Out:
#           2   3                   4   5                   6        7
# 0       NaN NaN    Start time (UTC) NaN      End time (UTC)  Flashes
# 1  [Mar 11] NaN  2017-070T05:05:49Z NaN  2017-070T06:38:24Z        3
# 2  [Mar 15] NaN  2017-074T17:07:10Z NaN  2017-074T18:39:46Z       61
# 3  [Mar 26] NaN  2017-085T23:10:13Z NaN  2017-086T00:42:48Z       34
# 4  [Mar 27] NaN  2017-086T22:19:01Z NaN  2017-086T23:51:36Z        2

# %%
sample.drop(sample.columns[1], axis=1, inplace=True)
# Out:
# C:\Users\ksury\AppData\Local\Temp\ipykernel_10704\2391841480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample.drop(sample.columns[1], axis=1, inplace=True)

# %%
sample.head()
# Out:
#           2                   4   5                   6        7
# 0       NaN    Start time (UTC) NaN      End time (UTC)  Flashes
# 1  [Mar 11]  2017-070T05:05:49Z NaN  2017-070T06:38:24Z        3
# 2  [Mar 15]  2017-074T17:07:10Z NaN  2017-074T18:39:46Z       61
# 3  [Mar 26]  2017-085T23:10:13Z NaN  2017-086T00:42:48Z       34
# 4  [Mar 27]  2017-086T22:19:01Z NaN  2017-086T23:51:36Z        2

# %%
sample.drop(sample.columns[2], axis=1, inplace=True)
# Out:
# C:\Users\ksury\AppData\Local\Temp\ipykernel_10704\2104091812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample.drop(sample.columns[2], axis=1, inplace=True)

# %%
sample.head()
# Out:
#           2                   4                   6        7
# 0       NaN    Start time (UTC)      End time (UTC)  Flashes
# 1  [Mar 11]  2017-070T05:05:49Z  2017-070T06:38:24Z        3
# 2  [Mar 15]  2017-074T17:07:10Z  2017-074T18:39:46Z       61
# 3  [Mar 26]  2017-085T23:10:13Z  2017-086T00:42:48Z       34
# 4  [Mar 27]  2017-086T22:19:01Z  2017-086T23:51:36Z        2

# %%
sample.columns = sample.iloc[0]

# %%
sample.head()
# Out:
# 0       NaN    Start time (UTC)      End time (UTC)  Flashes
# 0       NaN    Start time (UTC)      End time (UTC)  Flashes
# 1  [Mar 11]  2017-070T05:05:49Z  2017-070T06:38:24Z        3
# 2  [Mar 15]  2017-074T17:07:10Z  2017-074T18:39:46Z       61
# 3  [Mar 26]  2017-085T23:10:13Z  2017-086T00:42:48Z       34
# 4  [Mar 27]  2017-086T22:19:01Z  2017-086T23:51:36Z        2

# %%
sample.drop(index=0)
# Out:
# 0        NaN    Start time (UTC)      End time (UTC) Flashes
# 1   [Mar 11]  2017-070T05:05:49Z  2017-070T06:38:24Z       3
# 2   [Mar 15]  2017-074T17:07:10Z  2017-074T18:39:46Z      61
# 3   [Mar 26]  2017-085T23:10:13Z  2017-086T00:42:48Z      34
# 4   [Mar 27]  2017-086T22:19:01Z  2017-086T23:51:36Z       2
# 5   [Mar 29]  2017-088T11:21:05Z  2017-088T12:53:40Z       1
# 6   [Apr 09]  2017-099T17:24:56Z  2017-099T18:57:33Z      96
# 7   [Apr 23]  2017-113T11:40:33Z  2017-113T13:13:08Z      26
# 8   [Apr 26]  2017-116T10:39:47Z  2017-116T12:12:22Z     110
# 9   [Apr 29]  2017-119T09:39:31Z  2017-119T11:12:08Z      10
# 10  [May 04]  2017-124T20:51:01Z  2017-124T22:23:37Z       1
# 11  [May 14]  2017-134T16:59:18Z  2017-134T18:31:54Z       8
# 12  [May 17]  2017-137T15:58:59Z  2017-137T17:31:35Z       1
# 13  [May 20]  2017-140T01:05:28Z  2017-140T02:38:05Z       2
# 14  [May 20]  2017-140T14:58:57Z  2017-140T16:31:33Z       5
# ...

# %%
sample.to_csv('sample1.csv')

# %%
import pandas as pd
import requests
#import StringIO
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

f = StringIO.StringIO()
r = requests.get('https://lightning.nsstc.nasa.gov/isslisib/tmp/lisflashes-61.3.70.109.txt').content
f.write(r)

f.seek(0)
df = pd.DataFrame()

for x in f.readlines()[10:41]:
    df = df.append(pd.Series(x.split()),ignore_index=True)

df.columns = ['Flash time (UTC)','(    Lat,     Lon)',' Radiance' , 'Milliseconds' , 'Groups' , 'Events' ,'Orbit-ID']

df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [56], in <cell line: 9>()
#       6 except ImportError:
#       7     from io import StringIO
# ----> 9 f = StringIO.StringIO()
#      10 r = requests.get('https://lightning.nsstc.nasa.gov/isslisib/tmp/lisflashes-61.3.70.109.txt').content
#      11 f.write(r)
#
# AttributeError: type object '_io.StringIO' has no attribute 'StringIO'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Create an URL object
url = 'https://lightning.nsstc.nasa.gov/isslisib/tmp/lisflashes-61.3.70.109.txt'
# Create object page
page = requests.get(url)

# %%
# parser-lxml = Change html to Python friendly format
# Obtain page's information
soup = BeautifulSoup(page.text, 'lxml')
df=soup

# %%
df
# Out:
# <html><body><p>Flash time (UTC)                 (    Lat,     Lon)   Radiance  Milliseconds  Groups  Events Orbit-ID
# 2017-070T06:11:35.9504Z [Mar 11] (  7.992,  76.156)    1278353           518      14     103    50549
# 2017-070T06:11:45.4439Z [Mar 11] (  7.980,  76.126)     285429           291      10      28    50549
# 2017-070T06:12:16.6658Z [Mar 11] (  7.981,  76.125)      54275            82       4       8    50549
# 2017-074T17:32:36.0868Z [Mar 15] (  8.198,  75.917)    2135132           753      45     183   170710
# 2017-074T17:32:37.2577Z [Mar 15] (  8.275,  76.155)     209397           848      22      41   170710
# 2017-074T17:32:44.5971Z [Mar 15] (  8.135,  75.928)    2852093           816      35     164   170710
# 2017-074T17:32:46.2549Z [Mar 15] (  8.250,  76.388)      72645           218       8      14   170710
# 2017-074T17:32:48.5804Z [Mar 15] (  8.431,  76.497)     480908           463      13      55   170710
# ...
